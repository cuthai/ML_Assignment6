# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('thai_assignment6\output\data.csv')

# %%
df
# Out:
#       Seed Track_Name  Reset_Type Brain_Type  Learning_Rate  Time
# 0     None          R  Stop_Reset  QLearning           0.01   191
# 1     None          R  Stop_Reset  QLearning           0.01   914
# 2     None          R  Stop_Reset  QLearning           0.01   230
# 3     None          R  Stop_Reset  QLearning           0.01  1568
# 4     None          R  Stop_Reset  QLearning           0.01   289
# ...    ...        ...         ...        ...            ...   ...
# 1435  None          L  Stop_Reset      SARSA           0.20    51
# 1436  None          L  Stop_Reset      SARSA           0.20    98
# 1437  None          L  Stop_Reset      SARSA           0.20    50
# 1438  None          L  Stop_Reset      SARSA           0.20    83
# 1439  None          L  Stop_Reset      SARSA           0.20    45
#
# [1440 rows x 6 columns]

# %%
data = pd.DataFrame(df.loc[(df['Track_Name'] == 'R') &
                           (df['Reset_Type'] == 'Stop_Reset') &
                           (df['Brain_Type'] == 'QLearning')]
                    .groupby('Learning_Rate')['Time'].mean())

# Figure / axis set up
fig, ax = plt.subplots()

# We'll plot the list of params and their accuracy
ax.plot(data['Time'])

# Title
ax.set_title(rf'Learning Curves for R Track, QLearning, using Stop_Reset')

# X axis
ax.set_xlabel('Learning Rate')
ax.set_xlim(0, .2)
ax.set_xticks([.01, .02, .03, .04, .05, .06, .07, .08, .09, .1, .11, .12, .13, .14, .15, .16, .17, .18, .19, .2])
ax.set_xticklabels([.01, .02, .03, .04, .05, .06, .07, .08, .09, .1, .11, .12, .13, .14, .15, .16, .17, .18, .19, .2], rotation=45, fontsize=7)

# Y axis
ax.set_ylabel('Time')
ax.set_ylim(0, 1250)

# Saving
plt.savefig(f'thai_assignment6\output\\R_Track_QLearning_Stop.jpg')

# %%
data = pd.DataFrame(df.loc[(df['Track_Name'] == 'R') &
                           (df['Reset_Type'] == 'Stop_Reset') &
                           (df['Brain_Type'] == 'SARSA')]
                    .groupby('Learning_Rate')['Time'].mean())

# Figure / axis set up
fig, ax = plt.subplots()

# We'll plot the list of params and their accuracy
ax.plot(data['Time'])

# Title
ax.set_title(rf'Learning Curves for R Track, SARSA, using Stop_Reset')

# X axis
ax.set_xlabel('Learning Rate')
ax.set_xlim(0, .2)
ax.set_xticks([.01, .02, .03, .04, .05, .06, .07, .08, .09, .1, .11, .12, .13, .14, .15, .16, .17, .18, .19, .2])
ax.set_xticklabels([.01, .02, .03, .04, .05, .06, .07, .08, .09, .1, .11, .12, .13, .14, .15, .16, .17, .18, .19, .2], rotation=45, fontsize=7)

# Y axis
ax.set_ylabel('Time')
ax.set_ylim(0, 1250)

# Saving
plt.savefig(f'thai_assignment6\output\\R_Track_SARSA_Stop.jpg')

# %%
data = pd.DataFrame(df.loc[(df['Track_Name'] == 'O') &
                           (df['Reset_Type'] == 'Stop_Reset') &
                           (df['Brain_Type'] == 'QLearning')]
                    .groupby('Learning_Rate')['Time'].mean())

# Figure / axis set up
fig, ax = plt.subplots()

# We'll plot the list of params and their accuracy
ax.plot(data['Time'])

# Title
ax.set_title(rf'Learning Curves for O Track, QLearning, using Stop_Reset')

# X axis
ax.set_xlabel('Learning Rate')
ax.set_xlim(0, .2)
ax.set_xticks([.01, .02, .03, .04, .05, .06, .07, .08, .09, .1, .11, .12, .13, .14, .15, .16, .17, .18, .19, .2])
ax.set_xticklabels([.01, .02, .03, .04, .05, .06, .07, .08, .09, .1, .11, .12, .13, .14, .15, .16, .17, .18, .19, .2], rotation=45, fontsize=7)

# Y axis
ax.set_ylabel('Time')
ax.set_ylim(0, 500)

# Saving
plt.savefig(f'thai_assignment6\output\\O_Track_QLearning_Stop.jpg')

# %%
data = pd.DataFrame(df.loc[(df['Track_Name'] == 'O') &
                           (df['Reset_Type'] == 'Stop_Reset') &
                           (df['Brain_Type'] == 'SARSA')]
                    .groupby('Learning_Rate')['Time'].mean())

# Figure / axis set up
fig, ax = plt.subplots()

# We'll plot the list of params and their accuracy
ax.plot(data['Time'])

# Title
ax.set_title(rf'Learning Curves for O Track, SARSA, using Stop_Reset')

# X axis
ax.set_xlabel('Learning Rate')
ax.set_xlim(0, .2)
ax.set_xticks([.01, .02, .03, .04, .05, .06, .07, .08, .09, .1, .11, .12, .13, .14, .15, .16, .17, .18, .19, .2])
ax.set_xticklabels([.01, .02, .03, .04, .05, .06, .07, .08, .09, .1, .11, .12, .13, .14, .15, .16, .17, .18, .19, .2], rotation=45, fontsize=7)

# Y axis
ax.set_ylabel('Time')
ax.set_ylim(0, 500)

# Saving
plt.savefig(f'thai_assignment6\output\\O_Track_SARSA_Stop.jpg')

# %%
data = pd.DataFrame(df.loc[(df['Track_Name'] == 'L') &
                           (df['Reset_Type'] == 'Stop_Reset') &
                           (df['Brain_Type'] == 'QLearning')]
                    .groupby('Learning_Rate')['Time'].mean())

# Figure / axis set up
fig, ax = plt.subplots()

# We'll plot the list of params and their accuracy
ax.plot(data['Time'])

# Title
ax.set_title(rf'Learning Curves for L Track, QLearning, using Stop_Reset')

# X axis
ax.set_xlabel('Learning Rate')
ax.set_xlim(0, .2)
ax.set_xticks([.01, .02, .03, .04, .05, .06, .07, .08, .09, .1, .11, .12, .13, .14, .15, .16, .17, .18, .19, .2])
ax.set_xticklabels([.01, .02, .03, .04, .05, .06, .07, .08, .09, .1, .11, .12, .13, .14, .15, .16, .17, .18, .19, .2], rotation=45, fontsize=7)

# Y axis
ax.set_ylabel('Time')
ax.set_ylim(0, 100)

# Saving
plt.savefig(f'thai_assignment6\output\\L_Track_QLearning_Stop.jpg')

# %%
data = pd.DataFrame(df.loc[(df['Track_Name'] == 'L') &
                           (df['Reset_Type'] == 'Stop_Reset') &
                           (df['Brain_Type'] == 'SARSA')]
                    .groupby('Learning_Rate')['Time'].mean())

# Figure / axis set up
fig, ax = plt.subplots()

# We'll plot the list of params and their accuracy
ax.plot(data['Time'])

# Title
ax.set_title(rf'Learning Curves for L Track, SARSA, using Stop_Reset')

# X axis
ax.set_xlabel('Learning Rate')
ax.set_xlim(0, .2)
ax.set_xticks([.01, .02, .03, .04, .05, .06, .07, .08, .09, .1, .11, .12, .13, .14, .15, .16, .17, .18, .19, .2])
ax.set_xticklabels([.01, .02, .03, .04, .05, .06, .07, .08, .09, .1, .11, .12, .13, .14, .15, .16, .17, .18, .19, .2], rotation=45, fontsize=7)

# Y axis
ax.set_ylabel('Time')
ax.set_ylim(0, 100)

# Saving
plt.savefig(f'thai_assignment6\output\\L_Track_SARSA_Stop.jpg')

# %%
data = pd.DataFrame(df.loc[(df['Track_Name'] == 'R') &
                           (df['Reset_Type'] == 'Start_Reset') &
                           (df['Brain_Type'] == 'QLearning')]
                    .groupby('Learning_Rate')['Time'].mean())

# Figure / axis set up
fig, ax = plt.subplots()

# We'll plot the list of params and their accuracy
ax.plot(data['Time'])

# Title
ax.set_title(rf'Learning Curves for R Track, QLearning, using Start_Reset')

# X axis
ax.set_xlabel('Learning Rate')
ax.set_xlim(0, .2)
ax.set_xticks([.01, .02, .03, .04, .05, .06, .07, .08, .09, .1, .11, .12, .13, .14, .15, .16, .17, .18, .19, .2])
ax.set_xticklabels([.01, .02, .03, .04, .05, .06, .07, .08, .09, .1, .11, .12, .13, .14, .15, .16, .17, .18, .19, .2], rotation=45, fontsize=7)

# Y axis
ax.set_ylabel('Time')
ax.set_ylim(0, 200000)

# Saving
plt.savefig(f'thai_assignment6\output\\R_Track_QLearning_Start.jpg')

# %%
data = pd.DataFrame(df.loc[(df['Track_Name'] == 'R') &
                           (df['Reset_Type'] == 'Start_Reset') &
                           (df['Brain_Type'] == 'SARSA')]
                    .groupby('Learning_Rate')['Time'].mean())

# Figure / axis set up
fig, ax = plt.subplots()

# We'll plot the list of params and their accuracy
ax.plot(data['Time'])

# Title
ax.set_title(rf'Learning Curves for R Track, SARSA, using Start_Reset')

# X axis
ax.set_xlabel('Learning Rate')
ax.set_xlim(0, .2)
ax.set_xticks([.01, .02, .03, .04, .05, .06, .07, .08, .09, .1, .11, .12, .13, .14, .15, .16, .17, .18, .19, .2])
ax.set_xticklabels([.01, .02, .03, .04, .05, .06, .07, .08, .09, .1, .11, .12, .13, .14, .15, .16, .17, .18, .19, .2], rotation=45, fontsize=7)

# Y axis
ax.set_ylabel('Time')
ax.set_ylim(0, 200000)

# Saving
plt.savefig(f'thai_assignment6\output\\R_Track_SARSA_Start.jpg')
